# %% [markdown]
# ## 웹캠 스트리밍 인퍼런스

# %%
from YOLOv7_with_depthmap import YOLOv7
import cv2
import numpy as np

model = YOLOv7()
cap = cv2.VideoCapture(0)
while True:
    ret, img = cap.read()
    if ret == False:
        print('웹캠 수신 실패. 프로그램 종료')
        break
    # dummy 데이터 생성
    h, w, c = img.shape
    depth_map = np.random.randint(0, 256, (w, h), dtype=np.uint8)
    # 추론
    result = model.detect(bgr_img=img, depth_map=depth_map)
    print(result)
    cv2.imshow('YOLOv7 test', model.draw())
    if cv2.waitKey(1) & 0xFF == ord('q'):
        cv2.destroyAllWindows()
        break
# Out:
# GPU 사용 가능
#                  from  n    params  module                                  arguments
#   0                -1  1       928  models.common.Conv                      [3, 32, 3, 2, None, 1, LeakyReLU(negative_slope=0.1)]
#   1                -1  1     18560  models.common.Conv                      [32, 64, 3, 2, None, 1, LeakyReLU(negative_slope=0.1)]
#   2                -1  1      2112  models.common.Conv                      [64, 32, 1, 1, None, 1, LeakyReLU(negative_slope=0.1)]
#   3                -2  1      2112  models.common.Conv                      [64, 32, 1, 1, None, 1, LeakyReLU(negative_slope=0.1)]
#   4                -1  1      9280  models.common.Conv                      [32, 32, 3, 1, None, 1, LeakyReLU(negative_slope=0.1)]
#   5                -1  1      9280  models.common.Conv                      [32, 32, 3, 1, None, 1, LeakyReLU(negative_slope=0.1)]
#   6  [-1, -2, -3, -4]  1         0  models.common.Concat                    [1]
#   7                -1  1      8320  models.common.Conv                      [128, 64, 1, 1, None, 1, LeakyReLU(negative_slope=0.1)]
#   8                -1  1         0  models.common.MP                        []
#   9                -1  1      4224  models.common.Conv                      [64, 64, 1, 1, None, 1, LeakyReLU(negative_slope=0.1)]
#  10                -2  1      4224  models.common.Conv                      [64, 64, 1, 1, None, 1, LeakyReLU(negative_slope=0.1)]
#  11                -1  1     36992  models.common.Conv                      [64, 64, 3, 1, None, 1, LeakyReLU(negative_slope=0.1)]
#  12                -1  1     36992  models.common.Conv                      [64, 64, 3, 1, None, 1, LeakyReLU(negative_slope=0.1)]
#  13  [-1, -2, -3, -4]  1         0  models.common.Concat                    [1]
#  14                -1  1     33024  models.common.Conv                      [256, 128, 1, 1, None, 1, LeakyReLU(negative_slope=0.1)]
#  15                -1  1         0  models.common.MP                        []
#  16                -1  1     16640  models.common.Conv                      [128, 128, 1, 1, None, 1, LeakyReLU(negative_slope=0.1)]
#  17                -2  1     16640  models.common.Conv                      [128, 128, 1, 1, None, 1, LeakyReLU(negative_slope=0.1)]
#  18                -1  1    147712  models.common.Conv                      [128, 128, 3, 1, None, 1, LeakyReLU(negative_slope=0.1)]
#  19                -1  1    147712  models.common.Conv                      [128, 128, 3, 1, None, 1, LeakyReLU(negative_slope=0.1)]
#  20  [-1, -2, -3, -4]  1         0  models.common.Concat                    [1]
#  21                -1  1    131584  models.common.Conv                      [512, 256, 1, 1, None, 1, LeakyReLU(negative_slope=0.1)]
#  22                -1  1         0  models.common.MP                        []
#  23                -1  1     66048  models.common.Conv                      [256, 256, 1, 1, None, 1, LeakyReLU(negative_slope=0.1)]
#  24                -2  1     66048  models.common.Conv                      [256, 256, 1, 1, None, 1, LeakyReLU(negative_slope=0.1)]
#  25                -1  1    590336  models.common.Conv                      [256, 256, 3, 1, None, 1, LeakyReLU(negative_slope=0.1)]
#  26                -1  1    590336  models.common.Conv                      [256, 256, 3, 1, None, 1, LeakyReLU(negative_slope=0.1)]
#  27  [-1, -2, -3, -4]  1         0  models.common.Concat                    [1]
#  28                -1  1    525312  models.common.Conv                      [1024, 512, 1, 1, None, 1, LeakyReLU(negative_slope=0.1)]
#  29                -1  1    131584  models.common.Conv                      [512, 256, 1, 1, None, 1, LeakyReLU(negative_slope=0.1)]
#  30                -2  1    131584  models.common.Conv                      [512, 256, 1, 1, None, 1, LeakyReLU(negative_slope=0.1)]
#  31                -1  1         0  models.common.SP                        [5]
#  32                -2  1         0  models.common.SP                        [9]
#  33                -3  1         0  models.common.SP                        [13]
#  34  [-1, -2, -3, -4]  1         0  models.common.Concat                    [1]
#  35                -1  1    262656  models.common.Conv                      [1024, 256, 1, 1, None, 1, LeakyReLU(negative_slope=0.1)]
#  36          [-1, -7]  1         0  models.common.Concat                    [1]
#  37                -1  1    131584  models.common.Conv                      [512, 256, 1, 1, None, 1, LeakyReLU(negative_slope=0.1)]
#  38                -1  1     33024  models.common.Conv                      [256, 128, 1, 1, None, 1, LeakyReLU(negative_slope=0.1)]
#  39                -1  1         0  torch.nn.modules.upsampling.Upsample    [None, 2, 'nearest']
#  40                21  1     33024  models.common.Conv                      [256, 128, 1, 1, None, 1, LeakyReLU(negative_slope=0.1)]
#  41          [-1, -2]  1         0  models.common.Concat                    [1]
#  42                -1  1     16512  models.common.Conv                      [256, 64, 1, 1, None, 1, LeakyReLU(negative_slope=0.1)]
#  43                -2  1     16512  models.common.Conv                      [256, 64, 1, 1, None, 1, LeakyReLU(negative_slope=0.1)]
#  44                -1  1     36992  models.common.Conv                      [64, 64, 3, 1, None, 1, LeakyReLU(negative_slope=0.1)]
#  45                -1  1     36992  models.common.Conv                      [64, 64, 3, 1, None, 1, LeakyReLU(negative_slope=0.1)]
#  46  [-1, -2, -3, -4]  1         0  models.common.Concat                    [1]
#  47                -1  1     33024  models.common.Conv                      [256, 128, 1, 1, None, 1, LeakyReLU(negative_slope=0.1)]
#  48                -1  1      8320  models.common.Conv                      [128, 64, 1, 1, None, 1, LeakyReLU(negative_slope=0.1)]
#  49                -1  1         0  torch.nn.modules.upsampling.Upsample    [None, 2, 'nearest']
#  50                14  1      8320  models.common.Conv                      [128, 64, 1, 1, None, 1, LeakyReLU(negative_slope=0.1)]
#  51          [-1, -2]  1         0  models.common.Concat                    [1]
#  52                -1  1      4160  models.common.Conv                      [128, 32, 1, 1, None, 1, LeakyReLU(negative_slope=0.1)]
#  53                -2  1      4160  models.common.Conv                      [128, 32, 1, 1, None, 1, LeakyReLU(negative_slope=0.1)]
#  54                -1  1      9280  models.common.Conv                      [32, 32, 3, 1, None, 1, LeakyReLU(negative_slope=0.1)]
#  55                -1  1      9280  models.common.Conv                      [32, 32, 3, 1, None, 1, LeakyReLU(negative_slope=0.1)]
#  56  [-1, -2, -3, -4]  1         0  models.common.Concat                    [1]
#  57                -1  1      8320  models.common.Conv                      [128, 64, 1, 1, None, 1, LeakyReLU(negative_slope=0.1)]
#  58                -1  1     73984  models.common.Conv                      [64, 128, 3, 2, None, 1, LeakyReLU(negative_slope=0.1)]
#  59          [-1, 47]  1         0  models.common.Concat                    [1]
#  60                -1  1     16512  models.common.Conv                      [256, 64, 1, 1, None, 1, LeakyReLU(negative_slope=0.1)]
#  61                -2  1     16512  models.common.Conv                      [256, 64, 1, 1, None, 1, LeakyReLU(negative_slope=0.1)]
#  62                -1  1     36992  models.common.Conv                      [64, 64, 3, 1, None, 1, LeakyReLU(negative_slope=0.1)]
#  63                -1  1     36992  models.common.Conv                      [64, 64, 3, 1, None, 1, LeakyReLU(negative_slope=0.1)]
#  64  [-1, -2, -3, -4]  1         0  models.common.Concat                    [1]
#  65                -1  1     33024  models.common.Conv                      [256, 128, 1, 1, None, 1, LeakyReLU(negative_slope=0.1)]
#  66                -1  1    295424  models.common.Conv                      [128, 256, 3, 2, None, 1, LeakyReLU(negative_slope=0.1)]
#  67          [-1, 37]  1         0  models.common.Concat                    [1]
#  68                -1  1     65792  models.common.Conv                      [512, 128, 1, 1, None, 1, LeakyReLU(negative_slope=0.1)]
#  69                -2  1     65792  models.common.Conv                      [512, 128, 1, 1, None, 1, LeakyReLU(negative_slope=0.1)]
#  70                -1  1    147712  models.common.Conv                      [128, 128, 3, 1, None, 1, LeakyReLU(negative_slope=0.1)]
#  71                -1  1    147712  models.common.Conv                      [128, 128, 3, 1, None, 1, LeakyReLU(negative_slope=0.1)]
#  72  [-1, -2, -3, -4]  1         0  models.common.Concat                    [1]
#  73                -1  1    131584  models.common.Conv                      [512, 256, 1, 1, None, 1, LeakyReLU(negative_slope=0.1)]
#  74                57  1     73984  models.common.Conv                      [64, 128, 3, 1, None, 1, LeakyReLU(negative_slope=0.1)]
#  75                65  1    295424  models.common.Conv                      [128, 256, 3, 1, None, 1, LeakyReLU(negative_slope=0.1)]
#  76                73  1   1180672  models.common.Conv                      [256, 512, 3, 1, None, 1, LeakyReLU(negative_slope=0.1)]
#  77      [74, 75, 76]  1    229245  models.yolo.Detect                      [80, [[10, 13, 16, 30, 33, 23], [30, 61, 62, 45, 59, 119], [116, 90, 156, 198, 373, 326]], [128, 256, 512]]
# yolov7-tiny.pt checked
# yolov7.pt checked
# yolov7-X.pt checked
# yolov7-W6.pt checked
# c:\Users\nyan\anaconda3\envs\yolov7\lib\site-packages\torch\functional.py:512: UserWarning: torch.meshgrid: in an upcoming release, it will be required to pass the indexing argument. (Triggered internally at C:\cb\pytorch_1000000000000\work\aten\src\ATen\native\TensorShape.cpp:3588.)
#   return _VF.meshgrid(tensors, **kwargs)  # type: ignore[attr-defined]
# Model Summary: 255 layers, 6227101 parameters, 6227101 gradients, 13.9 GFLOPS
#
# YOLOR  2024-7-13 torch 2.3.1 CUDA:0 (NVIDIA GeForce RTX 3050 4GB Laptop GPU, 4095.5625MB)
# Adding autoShape...
# c:\Users\nyan\anaconda3\envs\yolov7\lib\site-packages\numpy\core\fromnumeric.py:3432: RuntimeWarning: Mean of empty slice.
#   return _methods._mean(a, axis=axis, dtype=dtype,
# c:\Users\nyan\anaconda3\envs\yolov7\lib\site-packages\numpy\core\_methods.py:190: RuntimeWarning: invalid value encountered in double_scalars
#   ret = ret.dtype.type(ret / rcount)
# [{'bbox': [119, 116, 599, 479], 'conf': 0.94, 'class_no': 0, 'name': 'person', 'inf_time': 0.645, 'depth': 126.54}, {'bbox': [580, 366, 610, 388], 'conf': 0.683, 'class_no': 2, 'name': 'car', 'inf_time': 0.645, 'depth': nan}, {'bbox': [612, 384, 640, 404], 'conf': 0.282, 'class_no': 2, 'name': 'car', 'inf_time': 0.645, 'depth': nan}]
# [{'bbox': [118, 115, 603, 479], 'conf': 0.939, 'class_no': 0, 'name': 'person', 'inf_time': 0.016, 'depth': 127.74}, {'bbox': [580, 367, 609, 388], 'conf': 0.61, 'class_no': 2, 'name': 'car', 'inf_time': 0.016, 'depth': nan}]
# [{'bbox': [118, 115, 603, 479], 'conf': 0.942, 'class_no': 0, 'name': 'person', 'inf_time': 0.027, 'depth': 126.93}, {'bbox': [580, 367, 608, 389], 'conf': 0.62, 'class_no': 2, 'name': 'car', 'inf_time': 0.027, 'depth': nan}]
# [{'bbox': [116, 115, 604, 479], 'conf': 0.947, 'class_no': 0, 'name': 'person', 'inf_time': 0.028, 'depth': 127.17}, {'bbox': [580, 367, 609, 389], 'conf': 0.606, 'class_no': 2, 'name': 'car', 'inf_time': 0.028, 'depth': nan}, {'bbox': [614, 386, 640, 403], 'conf': 0.261, 'class_no': 2, 'name': 'car', 'inf_time': 0.028, 'depth': nan}]
# [{'bbox': [116, 116, 604, 479], 'conf': 0.946, 'class_no': 0, 'name': 'person', 'inf_time': 0.009, 'depth': 127.92}, {'bbox': [580, 367, 608, 389], 'conf': 0.626, 'class_no': 2, 'name': 'car', 'inf_time': 0.009, 'depth': nan}, {'bbox': [614, 386, 640, 403], 'conf': 0.28, 'class_no': 2, 'name': 'car', 'inf_time': 0.009, 'depth': nan}]
# [{'bbox': [118, 115, 603, 479], 'conf': 0.947, 'class_no': 0, 'name': 'person', 'inf_time': 0.018, 'depth': 127.5}, {'bbox': [580, 367, 608, 389], 'conf': 0.443, 'class_no': 2, 'name': 'car', 'inf_time': 0.018, 'depth': nan}]
# [{'bbox': [121, 115, 603, 479], 'conf': 0.946, 'class_no': 0, 'name': 'person', 'inf_time': 0.018, 'depth': 127.76}, {'bbox': [580, 368, 608, 388], 'conf': 0.38, 'class_no': 2, 'name': 'car', 'inf_time': 0.018, 'depth': nan}, {'bbox': [615, 385, 640, 403], 'conf': 0.293, 'class_no': 2, 'name': 'car', 'inf_time': 0.018, 'depth': nan}]
# [{'bbox': [118, 115, 604, 479], 'conf': 0.947, 'class_no': 0, 'name': 'person', 'inf_time': 0.018, 'depth': 127.53}, {'bbox': [580, 367, 608, 388], 'conf': 0.371, 'class_no': 2, 'name': 'car', 'inf_time': 0.018, 'depth': nan}, {'bbox': [615, 385, 640, 403], 'conf': 0.29, 'class_no': 2, 'name': 'car', 'inf_time': 0.018, 'depth': nan}]
# [{'bbox': [120, 115, 604, 479], 'conf': 0.947, 'class_no': 0, 'name': 'person', 'inf_time': 0.025, 'depth': 127.34}, {'bbox': [580, 367, 608, 388], 'conf': 0.346, 'class_no': 2, 'name': 'car', 'inf_time': 0.025, 'depth': nan}]
# [{'bbox': [120, 115, 606, 479], 'conf': 0.947, 'class_no': 0, 'name': 'person', 'inf_time': 0.02, 'depth': 127.63}, {'bbox': [580, 367, 607, 388], 'conf': 0.308, 'class_no': 2, 'name': 'car', 'inf_time': 0.02, 'depth': nan}]
# [{'bbox': [118, 116, 605, 479], 'conf': 0.943, 'class_no': 0, 'name': 'person', 'inf_time': 0.015, 'depth': 126.58}, {'bbox': [580, 367, 607, 388], 'conf': 0.282, 'class_no': 2, 'name': 'car', 'inf_time': 0.015, 'depth': nan}]
# [{'bbox': [118, 116, 605, 479], 'conf': 0.946, 'class_no': 0, 'name': 'person', 'inf_time': 0.017, 'depth': 127.85}, {'bbox': [581, 367, 607, 388], 'conf': 0.317, 'class_no': 2, 'name': 'car', 'inf_time': 0.017, 'depth': nan}, {'bbox': [615, 385, 640, 403], 'conf': 0.298, 'class_no': 2, 'name': 'car', 'inf_time': 0.017, 'depth': nan}]
# [{'bbox': [116, 116, 606, 480], 'conf': 0.945, 'class_no': 0, 'name': 'person', 'inf_time': 0.021, 'depth': 127.33}, {'bbox': [580, 367, 606, 388], 'conf': 0.361, 'class_no': 2, 'name': 'car', 'inf_time': 0.021, 'depth': nan}, {'bbox': [614, 385, 640, 404], 'conf': 0.274, 'class_no': 2, 'name': 'car', 'inf_time': 0.021, 'depth': nan}]
# [{'bbox': [119, 115, 607, 479], 'conf': 0.945, 'class_no': 0, 'name': 'person', 'inf_time': 0.024, 'depth': 128.55}, {'bbox': [580, 367, 607, 388], 'conf': 0.266, 'class_no': 2, 'name': 'car', 'inf_time': 0.024, 'depth': nan}]
# [{'bbox': [119, 115, 607, 479], 'conf': 0.946, 'class_no': 0, 'name': 'person', 'inf_time': 0.018, 'depth': 126.99}]
# [{'bbox': [118, 115, 606, 480], 'conf': 0.942, 'class_no': 0, 'name': 'person', 'inf_time': 0.018, 'depth': 127.64}, {'bbox': [615, 385, 640, 403], 'conf': 0.277, 'class_no': 2, 'name': 'car', 'inf_time': 0.018, 'depth': nan}, {'bbox': [581, 367, 606, 387], 'conf': 0.264, 'class_no': 2, 'name': 'car', 'inf_time': 0.018, 'depth': nan}]
# [{'bbox': [115, 116, 604, 480], 'conf': 0.946, 'class_no': 0, 'name': 'person', 'inf_time': 0.018, 'depth': 128.44}]
# [{'bbox': [115, 116, 604, 480], 'conf': 0.945, 'class_no': 0, 'name': 'person', 'inf_time': 0.017, 'depth': 127.23}]
# [{'bbox': [114, 115, 601, 480], 'conf': 0.935, 'class_no': 0, 'name': 'person', 'inf_time': 0.0, 'depth': 127.46}, {'bbox': [580, 368, 605, 387], 'conf': 0.317, 'class_no': 2, 'name': 'car', 'inf_time': 0.0, 'depth': nan}]
# [{'bbox': [114, 117, 600, 480], 'conf': 0.944, 'class_no': 0, 'name': 'person', 'inf_time': 0.016, 'depth': 127.73}, {'bbox': [580, 368, 605, 386], 'conf': 0.316, 'class_no': 2, 'name': 'car', 'inf_time': 0.016, 'depth': nan}]
# [{'bbox': [114, 116, 601, 480], 'conf': 0.95, 'class_no': 0, 'name': 'person', 'inf_time': 0.016, 'depth': 127.56}]
# [{'bbox': [114, 117, 599, 480], 'conf': 0.947, 'class_no': 0, 'name': 'person', 'inf_time': 0.016, 'depth': 128.61}]
# [{'bbox': [116, 116, 594, 480], 'conf': 0.944, 'class_no': 0, 'name': 'person', 'inf_time': 0.014, 'depth': 126.51}, {'bbox': [581, 368, 604, 387], 'conf': 0.403, 'class_no': 2, 'name': 'car', 'inf_time': 0.014, 'depth': nan}, {'bbox': [615, 385, 640, 403], 'conf': 0.261, 'class_no': 2, 'name': 'car', 'inf_time': 0.014, 'depth': nan}]
# [{'bbox': [113, 115, 599, 479], 'conf': 0.947, 'class_no': 0, 'name': 'person', 'inf_time': 0.016, 'depth': 128.39}, {'bbox': [581, 367, 603, 387], 'conf': 0.384, 'class_no': 2, 'name': 'car', 'inf_time': 0.016, 'depth': nan}, {'bbox': [614, 385, 640, 404], 'conf': 0.375, 'class_no': 2, 'name': 'car', 'inf_time': 0.016, 'depth': nan}]
# [{'bbox': [112, 114, 587, 480], 'conf': 0.905, 'class_no': 0, 'name': 'person', 'inf_time': 0.025, 'depth': 128.58}]
# [{'bbox': [113, 112, 581, 480], 'conf': 0.92, 'class_no': 0, 'name': 'person', 'inf_time': 0.02, 'depth': 127.4}, {'bbox': [581, 368, 603, 387], 'conf': 0.483, 'class_no': 2, 'name': 'car', 'inf_time': 0.02, 'depth': nan}, {'bbox': [615, 385, 640, 404], 'conf': 0.336, 'class_no': 2, 'name': 'car', 'inf_time': 0.02, 'depth': nan}]
# [{'bbox': [109, 118, 568, 480], 'conf': 0.931, 'class_no': 0, 'name': 'person', 'inf_time': 0.018, 'depth': 127.48}, {'bbox': [580, 369, 601, 388], 'conf': 0.721, 'class_no': 2, 'name': 'car', 'inf_time': 0.018, 'depth': nan}, {'bbox': [613, 386, 639, 406], 'conf': 0.583, 'class_no': 2, 'name': 'car', 'inf_time': 0.018, 'depth': nan}]
# [{'bbox': [104, 118, 570, 480], 'conf': 0.924, 'class_no': 0, 'name': 'person', 'inf_time': 0.016, 'depth': 127.95}, {'bbox': [581, 368, 601, 388], 'conf': 0.612, 'class_no': 2, 'name': 'car', 'inf_time': 0.016, 'depth': nan}, {'bbox': [614, 386, 640, 405], 'conf': 0.563, 'class_no': 2, 'name': 'car', 'inf_time': 0.016, 'depth': nan}]
# [{'bbox': [94, 118, 564, 480], 'conf': 0.925, 'class_no': 0, 'name': 'person', 'inf_time': 0.016, 'depth': 127.22}, {'bbox': [614, 385, 640, 404], 'conf': 0.36, 'class_no': 2, 'name': 'car', 'inf_time': 0.016, 'depth': nan}]
# [{'bbox': [94, 117, 559, 480], 'conf': 0.921, 'class_no': 0, 'name': 'person', 'inf_time': 0.013, 'depth': 127.73}]
# [{'bbox': [94, 120, 561, 480], 'conf': 0.923, 'class_no': 0, 'name': 'person', 'inf_time': 0.023, 'depth': 127.98}, {'bbox': [581, 368, 600, 388], 'conf': 0.547, 'class_no': 2, 'name': 'car', 'inf_time': 0.023, 'depth': nan}, {'bbox': [614, 386, 640, 405], 'conf': 0.536, 'class_no': 2, 'name': 'car', 'inf_time': 0.023, 'depth': nan}]
# [{'bbox': [97, 123, 559, 480], 'conf': 0.921, 'class_no': 0, 'name': 'person', 'inf_time': 0.023, 'depth': 127.9}, {'bbox': [580, 369, 600, 389], 'conf': 0.551, 'class_no': 2, 'name': 'car', 'inf_time': 0.023, 'depth': nan}, {'bbox': [613, 388, 640, 406], 'conf': 0.512, 'class_no': 2, 'name': 'car', 'inf_time': 0.023, 'depth': nan}]
# [{'bbox': [96, 124, 556, 480], 'conf': 0.929, 'class_no': 0, 'name': 'person', 'inf_time': 0.01, 'depth': 126.95}, {'bbox': [613, 387, 640, 405], 'conf': 0.488, 'class_no': 2, 'name': 'car', 'inf_time': 0.01, 'depth': nan}, {'bbox': [580, 368, 600, 388], 'conf': 0.461, 'class_no': 2, 'name': 'car', 'inf_time': 0.01, 'depth': nan}]
# [{'bbox': [100, 124, 551, 480], 'conf': 0.906, 'class_no': 0, 'name': 'person', 'inf_time': 0.019, 'depth': 126.97}, {'bbox': [614, 385, 640, 405], 'conf': 0.332, 'class_no': 2, 'name': 'car', 'inf_time': 0.019, 'depth': nan}]
# [{'bbox': [95, 123, 554, 479], 'conf': 0.909, 'class_no': 0, 'name': 'person', 'inf_time': 0.02, 'depth': 127.72}, {'bbox': [613, 384, 640, 403], 'conf': 0.27, 'class_no': 2, 'name': 'car', 'inf_time': 0.02, 'depth': nan}]
# [{'bbox': [95, 122, 566, 479], 'conf': 0.89, 'class_no': 0, 'name': 'person', 'inf_time': 0.021, 'depth': 127.72}, {'bbox': [614, 385, 640, 404], 'conf': 0.306, 'class_no': 2, 'name': 'car', 'inf_time': 0.021, 'depth': nan}]
# [{'bbox': [98, 124, 558, 479], 'conf': 0.889, 'class_no': 0, 'name': 'person', 'inf_time': 0.019, 'depth': 127.25}, {'bbox': [614, 385, 640, 406], 'conf': 0.378, 'class_no': 2, 'name': 'car', 'inf_time': 0.019, 'depth': nan}]
# [{'bbox': [101, 124, 555, 477], 'conf': 0.919, 'class_no': 0, 'name': 'person', 'inf_time': 0.007, 'depth': 128.13}, {'bbox': [614, 386, 640, 405], 'conf': 0.47, 'class_no': 2, 'name': 'car', 'inf_time': 0.007, 'depth': nan}, {'bbox': [580, 367, 597, 387], 'conf': 0.362, 'class_no': 2, 'name': 'car', 'inf_time': 0.007, 'depth': nan}]
# [{'bbox': [104, 125, 559, 478], 'conf': 0.893, 'class_no': 0, 'name': 'person', 'inf_time': 0.014, 'depth': 127.19}, {'bbox': [614, 386, 640, 406], 'conf': 0.464, 'class_no': 2, 'name': 'car', 'inf_time': 0.014, 'depth': nan}, {'bbox': [580, 368, 597, 387], 'conf': 0.447, 'class_no': 2, 'name': 'car', 'inf_time': 0.014, 'depth': nan}, {'bbox': [384, 347, 454, 377], 'conf': 0.413, 'class_no': 79, 'name': 'toothbrush', 'inf_time': 0.014, 'depth': 132.7}]
# [{'bbox': [102, 124, 551, 478], 'conf': 0.917, 'class_no': 0, 'name': 'person', 'inf_time': 0.014, 'depth': 127.11}, {'bbox': [614, 385, 640, 406], 'conf': 0.399, 'class_no': 2, 'name': 'car', 'inf_time': 0.014, 'depth': nan}]
# [{'bbox': [98, 124, 627, 478], 'conf': 0.819, 'class_no': 0, 'name': 'person', 'inf_time': 0.013, 'depth': 128.13}]
# [{'bbox': [103, 124, 625, 478], 'conf': 0.79, 'class_no': 0, 'name': 'person', 'inf_time': 0.019, 'depth': 126.71}]
# [{'bbox': [108, 123, 623, 477], 'conf': 0.843, 'class_no': 0, 'name': 'person', 'inf_time': 0.01, 'depth': 126.05}]
# [{'bbox': [102, 122, 627, 477], 'conf': 0.864, 'class_no': 0, 'name': 'person', 'inf_time': 0.009, 'depth': 126.91}]
# [{'bbox': [95, 121, 627, 477], 'conf': 0.882, 'class_no': 0, 'name': 'person', 'inf_time': 0.009, 'depth': 128.0}]
# [{'bbox': [103, 120, 580, 478], 'conf': 0.892, 'class_no': 0, 'name': 'person', 'inf_time': 0.017, 'depth': 126.82}, {'bbox': [584, 348, 639, 377], 'conf': 0.371, 'class_no': 2, 'name': 'car', 'inf_time': 0.017, 'depth': nan}, {'bbox': [570, 352, 639, 478], 'conf': 0.301, 'class_no': 2, 'name': 'car', 'inf_time': 0.017, 'depth': nan}]
# [{'bbox': [103, 121, 573, 478], 'conf': 0.929, 'class_no': 0, 'name': 'person', 'inf_time': 0.009, 'depth': 126.93}]
# [{'bbox': [104, 123, 547, 478], 'conf': 0.91, 'class_no': 0, 'name': 'person', 'inf_time': 0.021, 'depth': 126.79}, {'bbox': [613, 388, 639, 407], 'conf': 0.277, 'class_no': 2, 'name': 'car', 'inf_time': 0.021, 'depth': nan}]
# [{'bbox': [100, 123, 554, 479], 'conf': 0.92, 'class_no': 0, 'name': 'person', 'inf_time': 0.016, 'depth': 126.78}, {'bbox': [613, 388, 640, 407], 'conf': 0.357, 'class_no': 2, 'name': 'car', 'inf_time': 0.016, 'depth': nan}]
# [{'bbox': [94, 122, 578, 478], 'conf': 0.935, 'class_no': 0, 'name': 'person', 'inf_time': 0.019, 'depth': 128.33}, {'bbox': [613, 388, 640, 406], 'conf': 0.413, 'class_no': 2, 'name': 'car', 'inf_time': 0.019, 'depth': nan}]
# [{'bbox': [93, 122, 602, 479], 'conf': 0.908, 'class_no': 0, 'name': 'person', 'inf_time': 0.015, 'depth': 128.66}, {'bbox': [614, 386, 640, 406], 'conf': 0.377, 'class_no': 2, 'name': 'car', 'inf_time': 0.015, 'depth': nan}]
# [{'bbox': [92, 121, 606, 478], 'conf': 0.924, 'class_no': 0, 'name': 'person', 'inf_time': 0.016, 'depth': 127.69}]
# [{'bbox': [93, 119, 610, 477], 'conf': 0.888, 'class_no': 0, 'name': 'person', 'inf_time': 0.016, 'depth': 127.31}]
# [{'bbox': [99, 121, 610, 478], 'conf': 0.882, 'class_no': 0, 'name': 'person', 'inf_time': 0.011, 'depth': 128.6}, {'bbox': [614, 387, 640, 406], 'conf': 0.386, 'class_no': 2, 'name': 'car', 'inf_time': 0.011, 'depth': nan}]
# [{'bbox': [102, 125, 607, 479], 'conf': 0.899, 'class_no': 0, 'name': 'person', 'inf_time': 0.002, 'depth': 128.47}]
# [{'bbox': [102, 125, 606, 478], 'conf': 0.879, 'class_no': 0, 'name': 'person', 'inf_time': 0.0, 'depth': 127.15}]
# [{'bbox': [97, 120, 608, 478], 'conf': 0.892, 'class_no': 0, 'name': 'person', 'inf_time': 0.011, 'depth': 127.28}]
# [{'bbox': [95, 120, 599, 478], 'conf': 0.922, 'class_no': 0, 'name': 'person', 'inf_time': 0.016, 'depth': 128.06}]
# [{'bbox': [96, 120, 602, 478], 'conf': 0.903, 'class_no': 0, 'name': 'person', 'inf_time': 0.011, 'depth': 127.12}, {'bbox': [614, 385, 640, 405], 'conf': 0.321, 'class_no': 2, 'name': 'car', 'inf_time': 0.011, 'depth': nan}]
# [{'bbox': [99, 121, 597, 478], 'conf': 0.9, 'class_no': 0, 'name': 'person', 'inf_time': 0.011, 'depth': 127.4}, {'bbox': [613, 387, 640, 405], 'conf': 0.326, 'class_no': 2, 'name': 'car', 'inf_time': 0.011, 'depth': nan}]
# [{'bbox': [96, 122, 600, 478], 'conf': 0.9, 'class_no': 0, 'name': 'person', 'inf_time': 0.014, 'depth': 127.31}, {'bbox': [613, 387, 640, 405], 'conf': 0.379, 'class_no': 2, 'name': 'car', 'inf_time': 0.014, 'depth': nan}]
# [{'bbox': [96, 122, 597, 478], 'conf': 0.922, 'class_no': 0, 'name': 'person', 'inf_time': 0.016, 'depth': 127.17}, {'bbox': [613, 388, 640, 406], 'conf': 0.362, 'class_no': 2, 'name': 'car', 'inf_time': 0.016, 'depth': nan}]
# [{'bbox': [95, 122, 587, 478], 'conf': 0.942, 'class_no': 0, 'name': 'person', 'inf_time': 0.017, 'depth': 127.2}, {'bbox': [613, 388, 640, 406], 'conf': 0.34, 'class_no': 2, 'name': 'car', 'inf_time': 0.017, 'depth': nan}]
# [{'bbox': [93, 122, 584, 478], 'conf': 0.939, 'class_no': 0, 'name': 'person', 'inf_time': 0.019, 'depth': 127.58}, {'bbox': [614, 385, 640, 404], 'conf': 0.337, 'class_no': 2, 'name': 'car', 'inf_time': 0.019, 'depth': nan}]
# [{'bbox': [91, 120, 590, 478], 'conf': 0.946, 'class_no': 0, 'name': 'person', 'inf_time': 0.016, 'depth': 126.94}]
# [{'bbox': [95, 120, 584, 478], 'conf': 0.94, 'class_no': 0, 'name': 'person', 'inf_time': 0.012, 'depth': 126.56}, {'bbox': [615, 385, 640, 403], 'conf': 0.267, 'class_no': 2, 'name': 'car', 'inf_time': 0.012, 'depth': nan}]
# [{'bbox': [96, 121, 584, 478], 'conf': 0.945, 'class_no': 0, 'name': 'person', 'inf_time': 0.008, 'depth': 127.81}, {'bbox': [614, 387, 640, 406], 'conf': 0.288, 'class_no': 2, 'name': 'car', 'inf_time': 0.008, 'depth': nan}]
# [{'bbox': [96, 124, 583, 478], 'conf': 0.948, 'class_no': 0, 'name': 'person', 'inf_time': 0.021, 'depth': 127.21}, {'bbox': [614, 388, 640, 406], 'conf': 0.375, 'class_no': 2, 'name': 'car', 'inf_time': 0.021, 'depth': nan}]
# [{'bbox': [95, 124, 581, 478], 'conf': 0.946, 'class_no': 0, 'name': 'person', 'inf_time': 0.015, 'depth': 128.23}, {'bbox': [613, 387, 640, 405], 'conf': 0.356, 'class_no': 2, 'name': 'car', 'inf_time': 0.015, 'depth': nan}]
# [{'bbox': [95, 121, 585, 478], 'conf': 0.941, 'class_no': 0, 'name': 'person', 'inf_time': 0.017, 'depth': 126.87}]
# [{'bbox': [96, 120, 584, 478], 'conf': 0.937, 'class_no': 0, 'name': 'person', 'inf_time': 0.016, 'depth': 126.41}]
# [{'bbox': [94, 121, 586, 478], 'conf': 0.943, 'class_no': 0, 'name': 'person', 'inf_time': 0.011, 'depth': 127.15}, {'bbox': [614, 386, 640, 405], 'conf': 0.378, 'class_no': 2, 'name': 'car', 'inf_time': 0.011, 'depth': nan}]
# [{'bbox': [96, 122, 589, 478], 'conf': 0.935, 'class_no': 0, 'name': 'person', 'inf_time': 0.016, 'depth': 127.1}, {'bbox': [613, 387, 640, 406], 'conf': 0.406, 'class_no': 2, 'name': 'car', 'inf_time': 0.016, 'depth': nan}]
# [{'bbox': [96, 123, 585, 478], 'conf': 0.941, 'class_no': 0, 'name': 'person', 'inf_time': 0.008, 'depth': 128.01}, {'bbox': [613, 387, 640, 406], 'conf': 0.381, 'class_no': 2, 'name': 'car', 'inf_time': 0.008, 'depth': nan}]
# [{'bbox': [96, 123, 587, 478], 'conf': 0.945, 'class_no': 0, 'name': 'person', 'inf_time': 0.01, 'depth': 128.22}, {'bbox': [613, 388, 640, 406], 'conf': 0.334, 'class_no': 2, 'name': 'car', 'inf_time': 0.01, 'depth': nan}]
# [{'bbox': [95, 123, 589, 478], 'conf': 0.935, 'class_no': 0, 'name': 'person', 'inf_time': 0.0, 'depth': 126.77}, {'bbox': [613, 387, 640, 406], 'conf': 0.332, 'class_no': 2, 'name': 'car', 'inf_time': 0.0, 'depth': nan}]
# [{'bbox': [97, 121, 590, 478], 'conf': 0.938, 'class_no': 0, 'name': 'person', 'inf_time': 0.0, 'depth': 128.5}]
# [{'bbox': [98, 120, 588, 478], 'conf': 0.941, 'class_no': 0, 'name': 'person', 'inf_time': 0.0, 'depth': 128.24}, {'bbox': [614, 385, 640, 404], 'conf': 0.318, 'class_no': 2, 'name': 'car', 'inf_time': 0.0, 'depth': nan}]
# [{'bbox': [94, 121, 589, 479], 'conf': 0.94, 'class_no': 0, 'name': 'person', 'inf_time': 0.002, 'depth': 128.07}, {'bbox': [614, 387, 640, 405], 'conf': 0.373, 'class_no': 2, 'name': 'car', 'inf_time': 0.002, 'depth': nan}]
# [{'bbox': [97, 122, 585, 478], 'conf': 0.944, 'class_no': 0, 'name': 'person', 'inf_time': 0.0, 'depth': 127.51}, {'bbox': [614, 388, 640, 407], 'conf': 0.437, 'class_no': 2, 'name': 'car', 'inf_time': 0.0, 'depth': nan}]
# [{'bbox': [94, 124, 590, 478], 'conf': 0.94, 'class_no': 0, 'name': 'person', 'inf_time': 0.01, 'depth': 127.02}, {'bbox': [613, 387, 640, 406], 'conf': 0.432, 'class_no': 2, 'name': 'car', 'inf_time': 0.01, 'depth': nan}]
# [{'bbox': [97, 122, 592, 478], 'conf': 0.936, 'class_no': 0, 'name': 'person', 'inf_time': 0.016, 'depth': 127.76}, {'bbox': [614, 386, 640, 405], 'conf': 0.361, 'class_no': 2, 'name': 'car', 'inf_time': 0.016, 'depth': nan}]
# [{'bbox': [99, 122, 591, 478], 'conf': 0.937, 'class_no': 0, 'name': 'person', 'inf_time': 0.014, 'depth': 127.55}, {'bbox': [614, 386, 640, 406], 'conf': 0.259, 'class_no': 2, 'name': 'car', 'inf_time': 0.014, 'depth': nan}]
# [{'bbox': [98, 122, 589, 478], 'conf': 0.931, 'class_no': 0, 'name': 'person', 'inf_time': 0.009, 'depth': 126.93}, {'bbox': [614, 387, 640, 407], 'conf': 0.32, 'class_no': 2, 'name': 'car', 'inf_time': 0.009, 'depth': nan}]
# [{'bbox': [99, 122, 586, 478], 'conf': 0.934, 'class_no': 0, 'name': 'person', 'inf_time': 0.017, 'depth': 127.68}, {'bbox': [614, 386, 640, 405], 'conf': 0.361, 'class_no': 2, 'name': 'car', 'inf_time': 0.017, 'depth': nan}]
# [{'bbox': [95, 122, 587, 479], 'conf': 0.934, 'class_no': 0, 'name': 'person', 'inf_time': 0.004, 'depth': 128.91}, {'bbox': [613, 387, 640, 406], 'conf': 0.343, 'class_no': 2, 'name': 'car', 'inf_time': 0.004, 'depth': nan}]
# [{'bbox': [93, 122, 581, 479], 'conf': 0.941, 'class_no': 0, 'name': 'person', 'inf_time': 0.0, 'depth': 127.08}, {'bbox': [613, 387, 640, 406], 'conf': 0.376, 'class_no': 2, 'name': 'car', 'inf_time': 0.0, 'depth': nan}]
# [{'bbox': [97, 123, 585, 478], 'conf': 0.942, 'class_no': 0, 'name': 'person', 'inf_time': 0.015, 'depth': 126.66}, {'bbox': [613, 387, 640, 406], 'conf': 0.333, 'class_no': 2, 'name': 'car', 'inf_time': 0.015, 'depth': nan}]
# [{'bbox': [99, 123, 588, 478], 'conf': 0.937, 'class_no': 0, 'name': 'person', 'inf_time': 0.0, 'depth': 127.54}, {'bbox': [613, 387, 640, 405], 'conf': 0.409, 'class_no': 2, 'name': 'car', 'inf_time': 0.0, 'depth': nan}]
# [{'bbox': [103, 122, 594, 478], 'conf': 0.911, 'class_no': 0, 'name': 'person', 'inf_time': 0.011, 'depth': 127.73}, {'bbox': [615, 385, 640, 404], 'conf': 0.299, 'class_no': 2, 'name': 'car', 'inf_time': 0.011, 'depth': nan}]
# [{'bbox': [106, 120, 588, 478], 'conf': 0.926, 'class_no': 0, 'name': 'person', 'inf_time': 0.0, 'depth': 127.58}, {'bbox': [614, 387, 640, 406], 'conf': 0.349, 'class_no': 2, 'name': 'car', 'inf_time': 0.0, 'depth': nan}]

# %% [markdown]
# ## 폴더에 있는 원하는 사진 인퍼런스

# %%
from YOLOv7_with_depthmap import YOLOv7
import cv2
import os
import numpy as np
import matplotlib.pyplot as plt
from IPython.display import display, Image
import io

def show_image(image):
    # 이미지를 BGR에서 RGB로 변환
    image_rgb = cv2.cvtColor(image, cv2.COLOR_BGR2RGB)
    # 이미지를 출력할 수 있는 형태로 변환
    _, buf = cv2.imencode('.png', cv2.cvtColor(image_rgb, cv2.COLOR_RGB2BGR))
    display(Image(data=buf.tobytes()))

model = YOLOv7()
path = 'test images'
for img_name in os.listdir(path):
    # 이미지 읽기
    img = cv2.imread(f'{path}/{img_name}')
    
    # dummy img 생성
    h, w, c = img.shape
    depth_map = np.random.randint(0, 256, (w, h), dtype=np.uint8)

    # 추론
    result = model.detect(bgr_img=img, depth_map=depth_map)
    print(result)
    show_image(model.draw())
# Out:
# GPU 사용 가능
#                  from  n    params  module                                  arguments
#   0                -1  1       928  models.common.Conv                      [3, 32, 3, 2, None, 1, LeakyReLU(negative_slope=0.1)]
#   1                -1  1     18560  models.common.Conv                      [32, 64, 3, 2, None, 1, LeakyReLU(negative_slope=0.1)]
#   2                -1  1      2112  models.common.Conv                      [64, 32, 1, 1, None, 1, LeakyReLU(negative_slope=0.1)]
#   3                -2  1      2112  models.common.Conv                      [64, 32, 1, 1, None, 1, LeakyReLU(negative_slope=0.1)]
#   4                -1  1      9280  models.common.Conv                      [32, 32, 3, 1, None, 1, LeakyReLU(negative_slope=0.1)]
#   5                -1  1      9280  models.common.Conv                      [32, 32, 3, 1, None, 1, LeakyReLU(negative_slope=0.1)]
#   6  [-1, -2, -3, -4]  1         0  models.common.Concat                    [1]
#   7                -1  1      8320  models.common.Conv                      [128, 64, 1, 1, None, 1, LeakyReLU(negative_slope=0.1)]
#   8                -1  1         0  models.common.MP                        []
#   9                -1  1      4224  models.common.Conv                      [64, 64, 1, 1, None, 1, LeakyReLU(negative_slope=0.1)]
#  10                -2  1      4224  models.common.Conv                      [64, 64, 1, 1, None, 1, LeakyReLU(negative_slope=0.1)]
#  11                -1  1     36992  models.common.Conv                      [64, 64, 3, 1, None, 1, LeakyReLU(negative_slope=0.1)]
#  12                -1  1     36992  models.common.Conv                      [64, 64, 3, 1, None, 1, LeakyReLU(negative_slope=0.1)]
#  13  [-1, -2, -3, -4]  1         0  models.common.Concat                    [1]
#  14                -1  1     33024  models.common.Conv                      [256, 128, 1, 1, None, 1, LeakyReLU(negative_slope=0.1)]
#  15                -1  1         0  models.common.MP                        []
#  16                -1  1     16640  models.common.Conv                      [128, 128, 1, 1, None, 1, LeakyReLU(negative_slope=0.1)]
#  17                -2  1     16640  models.common.Conv                      [128, 128, 1, 1, None, 1, LeakyReLU(negative_slope=0.1)]
#  18                -1  1    147712  models.common.Conv                      [128, 128, 3, 1, None, 1, LeakyReLU(negative_slope=0.1)]
#  19                -1  1    147712  models.common.Conv                      [128, 128, 3, 1, None, 1, LeakyReLU(negative_slope=0.1)]
#  20  [-1, -2, -3, -4]  1         0  models.common.Concat                    [1]
#  21                -1  1    131584  models.common.Conv                      [512, 256, 1, 1, None, 1, LeakyReLU(negative_slope=0.1)]
#  22                -1  1         0  models.common.MP                        []
#  23                -1  1     66048  models.common.Conv                      [256, 256, 1, 1, None, 1, LeakyReLU(negative_slope=0.1)]
#  24                -2  1     66048  models.common.Conv                      [256, 256, 1, 1, None, 1, LeakyReLU(negative_slope=0.1)]
#  25                -1  1    590336  models.common.Conv                      [256, 256, 3, 1, None, 1, LeakyReLU(negative_slope=0.1)]
#  26                -1  1    590336  models.common.Conv                      [256, 256, 3, 1, None, 1, LeakyReLU(negative_slope=0.1)]
#  27  [-1, -2, -3, -4]  1         0  models.common.Concat                    [1]
#  28                -1  1    525312  models.common.Conv                      [1024, 512, 1, 1, None, 1, LeakyReLU(negative_slope=0.1)]
#  29                -1  1    131584  models.common.Conv                      [512, 256, 1, 1, None, 1, LeakyReLU(negative_slope=0.1)]
#  30                -2  1    131584  models.common.Conv                      [512, 256, 1, 1, None, 1, LeakyReLU(negative_slope=0.1)]
#  31                -1  1         0  models.common.SP                        [5]
#  32                -2  1         0  models.common.SP                        [9]
#  33                -3  1         0  models.common.SP                        [13]
#  34  [-1, -2, -3, -4]  1         0  models.common.Concat                    [1]
#  35                -1  1    262656  models.common.Conv                      [1024, 256, 1, 1, None, 1, LeakyReLU(negative_slope=0.1)]
#  36          [-1, -7]  1         0  models.common.Concat                    [1]
#  37                -1  1    131584  models.common.Conv                      [512, 256, 1, 1, None, 1, LeakyReLU(negative_slope=0.1)]
#  38                -1  1     33024  models.common.Conv                      [256, 128, 1, 1, None, 1, LeakyReLU(negative_slope=0.1)]
#  39                -1  1         0  torch.nn.modules.upsampling.Upsample    [None, 2, 'nearest']
#  40                21  1     33024  models.common.Conv                      [256, 128, 1, 1, None, 1, LeakyReLU(negative_slope=0.1)]
#  41          [-1, -2]  1         0  models.common.Concat                    [1]
#  42                -1  1     16512  models.common.Conv                      [256, 64, 1, 1, None, 1, LeakyReLU(negative_slope=0.1)]
#  43                -2  1     16512  models.common.Conv                      [256, 64, 1, 1, None, 1, LeakyReLU(negative_slope=0.1)]
#  44                -1  1     36992  models.common.Conv                      [64, 64, 3, 1, None, 1, LeakyReLU(negative_slope=0.1)]
#  45                -1  1     36992  models.common.Conv                      [64, 64, 3, 1, None, 1, LeakyReLU(negative_slope=0.1)]
#  46  [-1, -2, -3, -4]  1         0  models.common.Concat                    [1]
#  47                -1  1     33024  models.common.Conv                      [256, 128, 1, 1, None, 1, LeakyReLU(negative_slope=0.1)]
#  48                -1  1      8320  models.common.Conv                      [128, 64, 1, 1, None, 1, LeakyReLU(negative_slope=0.1)]
#  49                -1  1         0  torch.nn.modules.upsampling.Upsample    [None, 2, 'nearest']
#  50                14  1      8320  models.common.Conv                      [128, 64, 1, 1, None, 1, LeakyReLU(negative_slope=0.1)]
#  51          [-1, -2]  1         0  models.common.Concat                    [1]
#  52                -1  1      4160  models.common.Conv                      [128, 32, 1, 1, None, 1, LeakyReLU(negative_slope=0.1)]
#  53                -2  1      4160  models.common.Conv                      [128, 32, 1, 1, None, 1, LeakyReLU(negative_slope=0.1)]
#  54                -1  1      9280  models.common.Conv                      [32, 32, 3, 1, None, 1, LeakyReLU(negative_slope=0.1)]
#  55                -1  1      9280  models.common.Conv                      [32, 32, 3, 1, None, 1, LeakyReLU(negative_slope=0.1)]
#  56  [-1, -2, -3, -4]  1         0  models.common.Concat                    [1]
#  57                -1  1      8320  models.common.Conv                      [128, 64, 1, 1, None, 1, LeakyReLU(negative_slope=0.1)]
#  58                -1  1     73984  models.common.Conv                      [64, 128, 3, 2, None, 1, LeakyReLU(negative_slope=0.1)]
#  59          [-1, 47]  1         0  models.common.Concat                    [1]
#  60                -1  1     16512  models.common.Conv                      [256, 64, 1, 1, None, 1, LeakyReLU(negative_slope=0.1)]
#  61                -2  1     16512  models.common.Conv                      [256, 64, 1, 1, None, 1, LeakyReLU(negative_slope=0.1)]
#  62                -1  1     36992  models.common.Conv                      [64, 64, 3, 1, None, 1, LeakyReLU(negative_slope=0.1)]
#  63                -1  1     36992  models.common.Conv                      [64, 64, 3, 1, None, 1, LeakyReLU(negative_slope=0.1)]
#  64  [-1, -2, -3, -4]  1         0  models.common.Concat                    [1]
#  65                -1  1     33024  models.common.Conv                      [256, 128, 1, 1, None, 1, LeakyReLU(negative_slope=0.1)]
#  66                -1  1    295424  models.common.Conv                      [128, 256, 3, 2, None, 1, LeakyReLU(negative_slope=0.1)]
#  67          [-1, 37]  1         0  models.common.Concat                    [1]
#  68                -1  1     65792  models.common.Conv                      [512, 128, 1, 1, None, 1, LeakyReLU(negative_slope=0.1)]
#  69                -2  1     65792  models.common.Conv                      [512, 128, 1, 1, None, 1, LeakyReLU(negative_slope=0.1)]
#  70                -1  1    147712  models.common.Conv                      [128, 128, 3, 1, None, 1, LeakyReLU(negative_slope=0.1)]
#  71                -1  1    147712  models.common.Conv                      [128, 128, 3, 1, None, 1, LeakyReLU(negative_slope=0.1)]
#  72  [-1, -2, -3, -4]  1         0  models.common.Concat                    [1]
#  73                -1  1    131584  models.common.Conv                      [512, 256, 1, 1, None, 1, LeakyReLU(negative_slope=0.1)]
#  74                57  1     73984  models.common.Conv                      [64, 128, 3, 1, None, 1, LeakyReLU(negative_slope=0.1)]
#  75                65  1    295424  models.common.Conv                      [128, 256, 3, 1, None, 1, LeakyReLU(negative_slope=0.1)]
#  76                73  1   1180672  models.common.Conv                      [256, 512, 3, 1, None, 1, LeakyReLU(negative_slope=0.1)]
#  77      [74, 75, 76]  1    229245  models.yolo.Detect                      [80, [[10, 13, 16, 30, 33, 23], [30, 61, 62, 45, 59, 119], [116, 90, 156, 198, 373, 326]], [128, 256, 512]]
# yolov7-tiny.pt checked
# yolov7.pt checked
# yolov7-X.pt checked
# yolov7-W6.pt checked
# Model Summary: 255 layers, 6227101 parameters, 6227101 gradients, 13.9 GFLOPS
#
# YOLOR  2024-7-13 torch 2.3.1 CUDA:0 (NVIDIA GeForce RTX 3050 4GB Laptop GPU, 4095.5625MB)
# Adding autoShape...
# [{'bbox': [105, 74, 141, 149], 'conf': 0.915, 'class_no': 0, 'name': 'person', 'inf_time': 0.027, 'depth': 125.98}]
# [{'bbox': [103, 0, 187, 156], 'conf': 0.903, 'class_no': 0, 'name': 'person', 'inf_time': 0.026, 'depth': 125.18}]
# [{'bbox': [60, 0, 121, 162], 'conf': 0.903, 'class_no': 0, 'name': 'person', 'inf_time': 0.031, 'depth': 128.13}]
